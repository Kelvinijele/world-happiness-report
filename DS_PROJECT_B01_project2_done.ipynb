# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
world = pd.read_csv('world-happiness-report-2021.csv')

# %%
world.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# 3                 10.878           0.983                     73.0
# 4                 10.932           0.942                     72.4
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                         0.949      -0.098                      0.186
# 1                         0.946       0.030                      0.179
# 2                         0.919       0.025                      0.292
# 3                         0.955       0.160                      0.673
# 4                         0.913       0.175                      0.338
#
#    Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 0                      2.43                             1.446
# 1                      2.43                             1.502
# 2                      2.43                             1.566
# 3                      2.43                             1.482
# 4                      2.43                             1.501
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                         1.106                                  0.741
# 1                         1.108                                  0.763
# 2                         1.079                                  0.816
# 3                         1.172                                  0.772
# 4                         1.079                                  0.753
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                       0.691                     0.124
# 1                                       0.686                     0.208
# 2                                       0.653                     0.204
# 3                                       0.698                     0.293
# 4                                       0.647                     0.302
#
#    Explained by: Perceptions of corruption  Dystopia + residual
# 0                                    0.481                3.253
# 1                                    0.485                2.868
# 2                                    0.413                2.839
# 3                                    0.170                2.967
# 4                                    0.384                2.798

# %%
world.drop(columns = {'Freedom to make life choices','Generosity','Perceptions of corruption','Ladder score in Dystopia','Logged GDP per capita','Social support','Healthy life expectancy'},inplace  = True)

# %%
world.head(2)
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
#
#    Explained by: Log GDP per capita  Explained by: Social support  \
# 0                             1.446                         1.106
# 1                             1.502                         1.108
#
#    Explained by: Healthy life expectancy  \
# 0                                  0.741
# 1                                  0.763
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                       0.691                     0.124
# 1                                       0.686                     0.208
#
#    Explained by: Perceptions of corruption  Dystopia + residual
# 0                                    0.481                3.253
# 1                                    0.485                2.868

# %%
world['Summarized Happiness'] = world['Explained by: Perceptions of corruption'] + world['Explained by: Generosity']+world['Explained by: Healthy life expectancy']+world['Explained by: Freedom to make life choices']+ world['Explained by: Social support'] + world['Explained by: Log GDP per capita']

# %%
world.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Explained by: Log GDP per capita  Explained by: Social support  \
# 0                             1.446                         1.106
# 1                             1.502                         1.108
# 2                             1.566                         1.079
# 3                             1.482                         1.172
# 4                             1.501                         1.079
#
#    Explained by: Healthy life expectancy  \
# 0                                  0.741
# 1                                  0.763
# 2                                  0.816
# 3                                  0.772
# 4                                  0.753
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                       0.691                     0.124
# 1                                       0.686                     0.208
# 2                                       0.653                     0.204
# 3                                       0.698                     0.293
# 4                                       0.647                     0.302
#
#    Explained by: Perceptions of corruption  Dystopia + residual  \
# 0                                    0.481                3.253
# 1                                    0.485                2.868
# 2                                    0.413                2.839
# 3                                    0.170                2.967
# 4                                    0.384                2.798
#
#    Summarized Happiness
# 0                 4.589
# 1                 4.752
# 2                 4.731
# 3                 4.587
# 4                 4.666

# %%
#world['max_rank'] = world['Summarized Happiness'].rank( ascending= False)

# %%
world.head(3)
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
#
#    Explained by: Log GDP per capita  Explained by: Social support  \
# 0                             1.446                         1.106
# 1                             1.502                         1.108
# 2                             1.566                         1.079
#
#    Explained by: Healthy life expectancy  \
# 0                                  0.741
# 1                                  0.763
# 2                                  0.816
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                       0.691                     0.124
# 1                                       0.686                     0.208
# 2                                       0.653                     0.204
#
#    Explained by: Perceptions of corruption  Dystopia + residual  \
# 0                                    0.481                3.253
# 1                                    0.485                2.868
# 2                                    0.413                2.839
#
#    Summarized Happiness
# 0                 4.589
# 1                 4.752
# 2                 4.731

# %%
#this is the position of nigeria in world happiness ranking
world[115:116]
# Out:
#     Country name  Regional indicator  Ladder score  \
# 115      Nigeria  Sub-Saharan Africa         4.759
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 115                           0.052         4.861         4.658
#
#      Explained by: Log GDP per capita  Explained by: Social support  \
# 115                             0.663                         0.625
#
#      Explained by: Healthy life expectancy  \
# 115                                  0.051
#
#      Explained by: Freedom to make life choices  Explained by: Generosity  \
# 115                                       0.433                     0.212
#
#      Explained by: Perceptions of corruption  Dystopia + residual  \
# 115                                    0.039                2.736
#
#      Summarized Happiness
# 115                 2.023

# %% [markdown]
# #2  appropriate chart, compare Nigeria and United State's level of happiness

# %%
#this is united states position in the ranking
world[18:19]
# Out:
#      Country name     Regional indicator  Ladder score  \
# 18  United States  North America and ANZ         6.951
#
#     Standard error of ladder score  upperwhisker  lowerwhisker  \
# 18                           0.049         7.047         6.856
#
#     Explained by: Log GDP per capita  Explained by: Social support  \
# 18                             1.533                          1.03
#
#     Explained by: Healthy life expectancy  \
# 18                                  0.621
#
#     Explained by: Freedom to make life choices  Explained by: Generosity  \
# 18                                       0.554                     0.252
#
#     Explained by: Perceptions of corruption  Dystopia + residual  \
# 18                                    0.154                2.807
#
#     Summarized Happiness
# 18                 4.144

# %%
world[115:116]
# Out:
#     Country name  Regional indicator  Ladder score  \
# 115      Nigeria  Sub-Saharan Africa         4.759
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 115                           0.052         4.861         4.658
#
#      Explained by: Log GDP per capita  Explained by: Social support  \
# 115                             0.663                         0.625
#
#      Explained by: Healthy life expectancy  \
# 115                                  0.051
#
#      Explained by: Freedom to make life choices  Explained by: Generosity  \
# 115                                       0.433                     0.212
#
#      Explained by: Perceptions of corruption  Dystopia + residual  \
# 115                                    0.039                2.736
#
#      Summarized Happiness
# 115                 2.023

# %%
index_names = ['1','2']
f ={'Summarized Happiness': [4.144, 2.023],'Countries':['United States','Nigeria']}

# %%
nigeria_uninted = pd.DataFrame(f)

# %%
#2. Using an appropriate chart, compare Nigeria and United State's level of happiness.
nigeria_uninted
# Out:
#    Summarized Happiness      Countries
# 0                 4.144  United States
# 1                 2.023        Nigeria

# %% [markdown]
# # 2 What 3 attributes would you suggest to have the most influence on the summarized happiness level?
# # Please show a linear model chart for each of these labels to proof their strong influence on summarized happiness level.

# %%
#CATEGORICAL PLOTS
fig = plt.figure(figsize=(10,6),)
ax1 = fig.add_axes([0.1,0.1,0.8,0.8])
ax1.set_title('LEVEL OF HAPPINESS',color='orange')

sn = sns.barplot(nigeria_uninted['Countries'],nigeria_uninted['Summarized Happiness'],estimator=max,palette='Accent')
plt.setp(sn.get_xticklabels(),rotation=45)
plt.show()
plt.tight_layout()

# %%
#sns.pairplot(world)

# %%
sns.lmplot(x='Ladder score',y='Summarized Happiness',data=world)

# %%
sns.lmplot(x='upperwhisker',y='Summarized Happiness',data=world)

# %%
sns.lmplot(x='lowerwhisker',y='Summarized Happiness',data=world)
#sns.lmplot(x='Quantity',y='Price',data=supply)

# %% [markdown]
# # 4to know to predict how the happiness level of any given country would change with varying Ladder score, Standard error of ladder score, upperwhisker, lowerwhisker, Logged GDP per capita, Social support, Healthy life expectancy,Freedom to make life choices, Generosity, Perceptions of corruption, Ladder score in Dystopia.
# # Note: Please give a short explanation (written as a comment) for your choice classifier used to develop your model.

# %%
world.columns

# %% [markdown]
# # 4. We want to know to predict how the happiness level of any given country would change with varying Ladder score, Standard error of ladder score, upperwhisker, lowerwhisker, Logged GDP per capita, Social support, Healthy life expectancy,Freedom to make life choices, Generosity, Perceptions of corruption, Ladder score in Dystopia.
# # Note: Please give a short explanation (written as a comment) for your choice classifier used to develop your model.

# %%
#drop dependent value
X = world.drop(['Regional indicator','Country name','Summarized Happiness'],axis=1)
y = world['Summarized Happiness']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
#from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LinearRegression

# %%
happy = LinearRegression()

# %%
happy.fit(X_train,y_train)

# %%
X[144:156]

# %% [markdown]
# #5 How happy would Nigeria be based on the following attribute scores (Ladder score=0.7.591, Standard error of ladder score=0.043, upperwhisker=7.7, lowerwhisker=7.523, Logged GDP per capita=10.910, Social support=0.901, Healthy life expectancy=72.001,Freedom to make life choices=0.951, Generosity=0.101, Perceptions of corruption=0.177, Ladder score in Dystopia=2.430)

# %%
happy.score(X_test,y_test)

# %%
predictions = [[0.7591,0.043,7.7,7.523,10.910,0.901,72.001,0.951,0.101,0.177,2.430]]

# %%
happy.predict(predictions)

# %%
# reason for using Linear regression as my classifier is because is best to estimate continous data (numeric data) not discrete data
#dependent variable  is continous and easy to interprete result
